# %% [markdown]
# TASK 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp       Parch
# count   418.000000  418.000000  418.000000  418.000000  418.000000  418.000000
# mean   1100.500000    0.363636    2.265550   29.393541    0.447368    0.392344
# std     120.810458    0.481622    0.841838   12.993749    0.896760    0.981429
# min     892.000000    0.000000    1.000000    0.170000    0.000000    0.000000
# 25%     996.250000    0.000000    1.000000   23.000000    0.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   25.000000    0.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   36.375000    1.000000    0.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000    9.000000

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 413        False     False   False  False  False   True  False  False   False
# 414        False     False   False  False  False  False  False  False   False
# 415        False     False   False  False  False  False  False  False   False
# 416        False     False   False  False  False   True  False  False   False
# 417        False     False   False  False  False   True  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
plt.show()

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived',data=df)
plt.show()

# %%
sns.set_style('whitegrid')
sns.countplot(x='SibSp',data=df)
plt.show()

# %%
sns.set_style('whitegrid')
sns.countplot(x='SibSp',hue='Sex',data=df,palette='RdBu_r')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.distplot(df['Age'].dropna(),kde=False,color='darkred',bins=20)
plt.show()
# Out:
# C:\Users\loges\AppData\Local\Temp\ipykernel_23908\399235248.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'].dropna(),kde=False,color='darkred',bins=20)

# %%
sns.set_style('whitegrid')
sns.countplot(x='Pclass',data=df)
plt.show()

# %%
sns.boxplot(x='Pclass',y='Age',data=df,palette='winter')
plt.show()
# Out:
# C:\Users\loges\AppData\Local\Temp\ipykernel_23908\409733001.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Pclass',y='Age',data=df,palette='winter')

# %%
def impute_age(cols):
    Age=cols.iloc[0]
    Pclass=cols.iloc[1]
    if pd.isnull(Age):
        if Pclass == 1:
            return 42
        elif Pclass==2:
            return 26
        else:
            return 24
    else:
         return Age

# %%
df['Age']=df[['Age','Pclass']].apply(impute_age,axis=1)

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
plt.show()

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sns.boxplot(x='Sex',y='Cabin',data=df,palette='winter')
plt.show()
# Out:
# C:\Users\loges\AppData\Local\Temp\ipykernel_23908\1352568739.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Sex',y='Cabin',data=df,palette='winter')

# %%
del df['Cabin']

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
plt.show()

# %%
df['Fare'].isnull().sum()
# Out:
# 1

# %%
df['Fare'].mean()
# Out:
# 35.627188489208635

# %%
df['Fare'].fillna('35.627188489208635',inplace=True)

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
plt.show()

# %%
co_mtx = df.corr(numeric_only=True)
print(co_mtx)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch
# PassengerId     1.000000 -0.023245 -0.026751 -0.042867  0.003818  0.043080
# Survived       -0.023245  1.000000 -0.108615  0.005661  0.099943  0.159120
# Pclass         -0.026751 -0.108615  1.000000 -0.529355  0.001087  0.018721
# Age            -0.042867  0.005661 -0.529355  1.000000 -0.078360 -0.054463
# SibSp           0.003818  0.099943  0.001087 -0.078360  1.000000  0.306895
# Parch           0.043080  0.159120  0.018721 -0.054463  0.306895  1.000000

# %%
sns.heatmap(co_mtx, cmap="YlGnBu", annot=True)
plt.show()
